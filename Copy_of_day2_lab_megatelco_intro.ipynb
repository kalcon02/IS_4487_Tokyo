# %% [markdown]
# <a href="https://colab.research.google.com/github/kalcon02/IS_4487_Tokyo/blob/main/Copy_of_day2_lab_megatelco_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 2 Lab, IS 4487
#
# Outline
#
# - Loading installed packages
# - Inspect data
# - Clean data
# - Summarize data

# %% [markdown]
# # Notebook Instructions
#
# Again, remember to save a copy of the notebook in Drive so that you can save your changes.
#
# When you are done revising this notebook save your changes to GitHub and upload the URL for the file to Canvas for the assignment.

# %% [markdown]
# # Clean and Prepare the MegaTelCo Data

# %% [markdown]
# ##Load Libraries
#
# Remember, we will be using:
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Load the Data
#
# In this case we will load  the MegaTelCo data directly from the URL in GitHub.

# %%
mtc = pd.read_csv("https://raw.githubusercontent.com/jefftwebb/is_4487_base/dd870389117d5b24eee7417d5378d80496555130/Labs/DataSets/megatelco_leave_survey.csv")

# %% [markdown]
# Examine the data quickly for mistakes and to get a sense of the variables:

# %%
#look at the top rows
mtc.head(10)
# Out:
#   college  income  overage  leftover   house  handset_price  \
# 0     one   23859       70         0  519105            154
# 1    zero   72466       67        16  271182            262
# 2    zero   30883       60         0  647281            211
# 3     one   44512        0        22  754958            232
# 4    zero   70535        0         0  653421            310
# 5    zero  143987        0        56  896544            778
# 6     one   96668       79        24  259329            365
# 7     one   50083        0         0  160335            266
# 8     one  104392        0         0  247836            778
# 9     one   37852        0        74  264893            857
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 0                          5.0                      8                   low
# 1                          5.0                      5                   low
# 2                          3.0                      8                   low
# 3                          0.0                      5                   low
# 4                          0.0                     14                   low
# 5                          5.0                      1                   low
# 6                          5.0                      6                   low
# 7                          5.0                     10                   low
# 8                          1.0                      8                  high
# 9                          0.0                      2                   low
#
#   reported_usage_level considering_change_of_plan  leave     id
# 0                  low                        yes  LEAVE   8183
# 1                  low                        yes  LEAVE  12501
# 2                  low                        yes   STAY   7425
# 3                  low                         no  LEAVE  13488
# 4                  low                        yes   STAY  11389
# 5                 high                        yes   STAY  14674
# 6                  avg                        yes  LEAVE  19100
# 7                 high                        yes   STAY  18170
# 8                  low                         no  LEAVE   3201
# 9                  low                        yes  LEAVE  12612

# %%
#look at last rows
mtc.tail(10)
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 4990     one  158179      226        21  269368            478
# 4991     one   75711       47         0  519512            326
# 4992     one   34039       59         0  541872            165
# 4993    zero   88713        0        70  587559            319
# 4994    zero  123820        0        71  608639            888
# 4995    zero   93699       26        56  385632            384
# 4996    zero   25806       67        87  691020            142
# 4997     one   97033      138        28  710559            311
# 4998    zero   91558      229        15  853464            379
# 4999     one  115943      200        42  173038            459
#
#       over_15mins_calls_per_month  average_call_duration  \
# 4990                         18.0                      5
# 4991                          4.0                     12
# 4992                          3.0                     10
# 4993                          0.0                      2
# 4994                          1.0                      2
# 4995                          5.0                      1
# 4996                          4.0                      2
# 4997                         10.0                      2
# 4998                         27.0                      4
# 4999                         24.0                      2
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 4990                   avg                 high                        yes
# 4991                  high                 high                        yes
# 4992                   low                 high                        yes
# 4993                   low                  low                        yes
# 4994                   low                 high                        yes
# 4995                  high                  low                        yes
# 4996                  high                  low                         no
# 4997                   low                 high                        yes
# 4998                  high                  low                         no
# 4999                  high                 high                        yes
#
#       leave     id
# 4990  LEAVE  18481
# 4991   STAY   9790
# 4992   STAY  19985
# 4993  LEAVE  17220
# 4994   STAY  10396
# 4995  LEAVE  19270
# 4996   STAY  14549
# 4997   STAY   9972
# 4998   STAY  12685
# 4999  LEAVE  13561

# %%
#get a summary of the dataset
mtc.describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    5000.000000  5000.000000  5000.000000     5000.000000   5.000000e+03
# mean    79912.948400    85.119200    24.243600   493656.326600   7.876236e+02
# std     41703.042384    85.655622    26.847496   254287.193865   2.828291e+04
# min    -28811.000000     0.000000     0.000000  -796132.000000   1.300000e+02
# 25%     41592.500000     0.000000     0.000000   260586.500000   2.190000e+02
# 50%     75041.500000    59.000000    15.000000   451865.500000   3.220000e+02
# 75%    115475.000000   177.000000    42.000000   701608.750000   5.280000e+02
# max    159938.000000   335.000000    89.000000  1000000.000000   2.000234e+06
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4997.000000            5000.000000   5000.000000
# mean                      7.744647               5.958800  10036.639400
# std                       8.806070               4.390417   5813.620304
# min                       0.000000               1.000000      2.000000
# 25%                       1.000000               2.000000   4950.500000
# 50%                       4.000000               5.000000  10126.000000
# 75%                      14.000000               9.000000  15085.250000
# max                      29.000000              15.000000  20000.000000

# %%
#look at the datatypes
mtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      5000 non-null   object
#  1   income                       5000 non-null   int64
#  2   overage                      5000 non-null   int64
#  3   leftover                     5000 non-null   int64
#  4   house                        5000 non-null   int64
#  5   handset_price                5000 non-null   int64
#  6   over_15mins_calls_per_month  4997 non-null   float64
#  7   average_call_duration        5000 non-null   int64
#  8   reported_satisfaction        5000 non-null   object
#  9   reported_usage_level         5000 non-null   object
#  10  considering_change_of_plan   5000 non-null   object
#  11  leave                        5000 non-null   object
#  12  id                           5000 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 507.9+ KB

# %% [markdown]
# Did you notice anything unusual about the amounts for `house`?  And what about `handset_price` and `income`? The data needs to be cleaned by selecting and filtering the data.

# %% [markdown]
# ## Data Selection and Filtering in Pandas
#
# Data selection and filtering are essential techniques for working with Pandas DataFrames. They allow you to extract specific subsets of data based on certain conditions.

# %% [markdown]
# ## Selecting Specific Columns
#
# Square bracket subsetting, or indexing, is a way to access specific rows and columns of a DataFrame. When you use square brackets, `[]`, with a DataFrame  you can pass in:
#
# - A single column name to select a single column (returns a Series)
# - A list of column names to select multiple columns (returns a DataFrame)
# - A boolean mask to select rows based on a condition
# - A slice to select a range of rows
#
# For example, `mtc['college']` selects the `college` column as a Series, while `mtc[['college', 'income']]` selects the `college` and `income` columns as a DataFrame.

# %%
mtc['college']
# Out:
# 0        one
# 1       zero
# 2       zero
# 3        one
# 4       zero
#         ...
# 4995    zero
# 4996    zero
# 4997     one
# 4998    zero
# 4999     one
# Name: college, Length: 5000, dtype: object

# %%
mtc[['college', 'income']]
# Out:
#      college  income
# 0        one   23859
# 1       zero   72466
# 2       zero   30883
# 3        one   44512
# 4       zero   70535
# ...      ...     ...
# 4995    zero   93699
# 4996    zero   25806
# 4997     one   97033
# 4998    zero   91558
# 4999     one  115943
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## Your Turn: Selecting Columns
#
# 1. Select the `overage` column from `mtc`.
# 2. Select the `overage` *and* `leftover` columns from `mtc`.

# %%
# Your code goes here
mtc['overage']
# Out:
# 0        70
# 1        67
# 2        60
# 3         0
# 4         0
#        ...
# 4995     26
# 4996     67
# 4997    138
# 4998    229
# 4999    200
# Name: overage, Length: 5000, dtype: int64

# %%
# Your code goes here
mtc[["overage", 'leftover']]
# Out:
#       overage  leftover
# 0          70         0
# 1          67        16
# 2          60         0
# 3           0        22
# 4           0         0
# ...       ...       ...
# 4995       26        56
# 4996       67        87
# 4997      138        28
# 4998      229        15
# 4999      200        42
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## Filtering Rows with Boolean Masks
#
# Boolean masking is a powerful technique for filtering rows based on certain conditions. You create a boolean mask by applying a logical condition to a DataFrame, which returns  True/False values. You can then use this mask to select the rows where the condition is True.

# %%
# Here is the mask:
mtc["handset_price"] > 1000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: handset_price, Length: 5000, dtype: bool

# %%
# Now, filter with the mask:
mtc[mtc["handset_price"] > 1000]
# Out:
#     college  income  overage  leftover   house  handset_price  \
# 299    zero   83525      246        53  308636        2000234
#
#      over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 299                         27.0                      1                   low
#
#     reported_usage_level considering_change_of_plan  leave     id
# 299                 high                         no  LEAVE  14137

# %% [markdown]
# Notice that the number of rows has gone from 5000 down to 1.  Of course, for cleaning we would want to *exclude* this row.

# %% [markdown]
# ## Your Turn:  Data Cleaning
#
# 1.  Use a boolean mask to filter out rows with mistakes using three logical conditions:
#   - remove the outlier in `handset_price`
#   - remove rows with negative values of `income` and `house`
# 2. Save the cleaned data in a new DataFrame, `mtc_clean`.
# 3. Summarize this new DataFrame to verify that your changes worked.

# %%
# Your code goes here
mtc[ (mtc["handset_price"] < 1000) & (mtc["house"] >= 0) & (mtc["income"] >= 0) ]
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 0        one   23859       70         0  519105            154
# 1       zero   72466       67        16  271182            262
# 2       zero   30883       60         0  647281            211
# 3        one   44512        0        22  754958            232
# 4       zero   70535        0         0  653421            310
# ...      ...     ...      ...       ...     ...            ...
# 4995    zero   93699       26        56  385632            384
# 4996    zero   25806       67        87  691020            142
# 4997     one   97033      138        28  710559            311
# 4998    zero   91558      229        15  853464            379
# 4999     one  115943      200        42  173038            459
#
#       over_15mins_calls_per_month  average_call_duration  \
# 0                             5.0                      8
# 1                             5.0                      5
# 2                             3.0                      8
# 3                             0.0                      5
# 4                             0.0                     14
# ...                           ...                    ...
# 4995                          5.0                      1
# 4996                          4.0                      2
# 4997                         10.0                      2
# 4998                         27.0                      4
# 4999                         24.0                      2
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 0                      low                  low                        yes
# 1                      low                  low                        yes
# 2                      low                  low                        yes
# 3                      low                  low                         no
# 4                      low                  low                        yes
# ...                    ...                  ...                        ...
# 4995                  high                  low                        yes
# 4996                  high                  low                         no
# 4997                   low                 high                        yes
# 4998                  high                  low                         no
# 4999                  high                 high                        yes
#
#       leave     id
# 0     LEAVE   8183
# 1     LEAVE  12501
# 2      STAY   7425
# 3     LEAVE  13488
# 4      STAY  11389
# ...     ...    ...
# 4995  LEAVE  19270
# 4996   STAY  14549
# 4997   STAY   9972
# 4998   STAY  12685
# 4999  LEAVE  13561
#
# [4997 rows x 13 columns]

# %%
# Your code goes here
filtered_mtc = mtc[ (mtc["handset_price"] < 1000) & (mtc["house"] >= 0) & (mtc["income"] >= 0) ]
mtc_clean = filtered_mtc.copy()

# %%
filtered_mtc.describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    4997.000000  4997.000000  4997.000000     4997.000000    4997.000000
# mean    79918.829498    85.116270    24.247549   494019.823294     387.558935
# std     41673.392025    85.638266    26.848091   253648.357473     213.614256
# min     20028.000000     0.000000     0.000000   150305.000000     130.000000
# 25%     41593.000000     0.000000     0.000000   260729.000000     219.000000
# 50%     75026.000000    59.000000    15.000000   452277.000000     322.000000
# 75%    115464.000000   177.000000    42.000000   701614.000000     528.000000
# max    159938.000000   335.000000    89.000000  1000000.000000     899.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4994.000000            4997.000000   4997.000000
# mean                      7.739287               5.957174  10034.365619
# std                       8.802897               4.388938   5814.189195
# min                       0.000000               1.000000      2.000000
# 25%                       1.000000               2.000000   4949.000000
# 50%                       4.000000               5.000000  10125.000000
# 75%                      14.000000               9.000000  15084.000000
# max                      29.000000              15.000000  20000.000000

# %% [markdown]
# 3. This dataframe entails filtered data categories, handset price lower than 1000, house greater or equal to zero, and income greater or equal to zero.

# %% [markdown]
# # Summarize the Data
#
#  Previously we used a built-in summary function, `info()`, to summarize the numeric columns in a dataset. However, we can write code to do more complicated data summaries.
#
#  Question:  What is average value of `house` at the two levels of `leave`?  (We call this a conditional mean because it is *conditional* on the value of `leave`.)

# %%
mtc_clean[['house','leave']].groupby('leave').mean().round(2)
# Out:
#            house
# leave
# LEAVE  439255.26
# STAY   547591.97

# %% [markdown]
# Details:
#
# - `[[...]]`: Used to select specific columns (`house` and `leave`) from `mtc_clean`.
# - `groupby()`:  Groups the data by the `leave` column, creating separate groups for each unique value in `leave`.
# - `mean()`: Calculates the average of the `house` column for each group created by `groupby()`.
# - `round(2)`: Rounds the resulting mean values to 2 decimal places.

# %% [markdown]
#  Conclusion?  Stayers have substantially more expensive homes.

# %% [markdown]
# ## Your Turn: Calculate Additional Stats
#
# Use `mtc_clean` to:
#
# 1. Calculate means conditional on leave for `income` and `overage`.
# 2. Calculate *median* income for leavers and stayers. (Hint:  use the Gemini AI tool to figure out what function will calculate a median.)
# 3. Calculate the 25th and 75th percentiles for `income`.  (Again use Gemini for help.)

# %%
# Your code goes here
filtered_mtc[['income','leave']].groupby('leave').mean().round(2)
filtered_mtc[['overage','leave']].groupby('leave').mean().round(2)
# Out:
#        overage
# leave
# LEAVE   104.70
# STAY     65.95

# %%
# Your code goes here
filtered_mtc[['income','leave']].groupby('leave').median().round(2)
filtered_mtc[['overage','leave']].groupby('leave').median().round(2)
# Out:
#        overage
# leave
# LEAVE     72.0
# STAY      47.0

# %%
# Your code goes here
filtered_mtc[['income','leave']].groupby('leave').quantile(0.25).round(2)
filtered_mtc[['income','leave']].groupby('leave').quantile(0.75).round(2)
# Out:
#          income
# leave
# LEAVE  122746.0
# STAY   106000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['income'].plot(kind='hist', bins=20, title='income')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['income'].plot(kind='line', figsize=(8, 4), title='income')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Your code goes here

# %% [markdown]
# # Functions
#
# - `pd.read_csv()`:  Reads a CSV file into a pandas DataFrame.
# - `.head()`: Returns the first n rows of a DataFrame or Series (default is 5).
# - `.tail()`: Returns the last n rows of a DataFrame or Series (default is 5).
# - `.describe()`: Generates descriptive statistics of a DataFrame or Series.
# - `.info()`: Prints a concise summary of a DataFrame, including column names, non-null counts, and data types.
# - `[]` and `[[ ]]` (indexing):  Used to select specific columns or rows from a DataFrame.
# - `.groupby()`: Groups DataFrame using a mapper or by a Series of columns.
# - `.mean()`:  Returns the mean of the values for the requested axis.
# - `.round()`:  Rounds a number or DataFrame to a specified number of decimal places.
